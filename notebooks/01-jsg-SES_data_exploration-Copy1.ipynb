# %%
import sys
print(f'Interpreter dir: {sys.executable}')
import os

if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('../')
    
print(f'Working dir: {os.getcwd()}')
# %load_ext autoreload
# %autoreload 2
# Out:
# Interpreter dir: /Users/jsg/Documents/GitHub/water_hackathlon/.venv_waterhack/bin/python3
# Working dir: /Users/jsg/Documents/GitHub/water_hackathlon

# %%
import pandas as pd

# %% [markdown]
# # Explore SES dataset

# %%
df1 = pd.read_csv("data/raw/SES-EFF13 (Flow)_15 Minute Flow_(m3hr).csv")
df1
# Out:
#         Site        Sensor         Date Of Read  Original Value (m3/hr)  \
# 0      EFF13  EFF13 (Flow)  01/04/2019 00:00:00                   10.48
# 1      EFF13  EFF13 (Flow)  01/04/2019 00:15:00                   11.60
# 2      EFF13  EFF13 (Flow)  01/04/2019 00:30:00                   11.28
# 3      EFF13  EFF13 (Flow)  01/04/2019 00:45:00                    9.88
# 4      EFF13  EFF13 (Flow)  01/04/2019 01:00:00                   10.40
# ...      ...           ...                  ...                     ...
# 48859  EFF13  EFF13 (Flow)  21/08/2020 22:45:00                     NaN
# 48860  EFF13  EFF13 (Flow)  21/08/2020 23:00:00                     NaN
# 48861  EFF13  EFF13 (Flow)  21/08/2020 23:15:00                     NaN
# 48862  EFF13  EFF13 (Flow)  21/08/2020 23:30:00                     NaN
# 48863  EFF13  EFF13 (Flow)  21/08/2020 23:45:00                     NaN
#
#        Validated Value (m3/hr) Validation Flag
# 0                        10.48               O
# ...

# %%
df2 = pd.read_csv("data/raw/SES-KNT11 (Flow)_15 Minute Flow_(m3hr).csv")
df2
# Out:
#         Site        Sensor         Date Of Read  Original Value (m3/hr)  \
# 0      KNT11  KNT11 (Flow)  01/04/2019 00:00:00                    7.32
# 1      KNT11  KNT11 (Flow)  01/04/2019 00:15:00                    7.24
# 2      KNT11  KNT11 (Flow)  01/04/2019 00:30:00                    7.32
# 3      KNT11  KNT11 (Flow)  01/04/2019 00:45:00                    7.20
# 4      KNT11  KNT11 (Flow)  01/04/2019 01:00:00                    7.68
# ...      ...           ...                  ...                     ...
# 48859  KNT11  KNT11 (Flow)  21/08/2020 22:45:00                     NaN
# 48860  KNT11  KNT11 (Flow)  21/08/2020 23:00:00                     NaN
# 48861  KNT11  KNT11 (Flow)  21/08/2020 23:15:00                     NaN
# 48862  KNT11  KNT11 (Flow)  21/08/2020 23:30:00                     NaN
# 48863  KNT11  KNT11 (Flow)  21/08/2020 23:45:00                     NaN
#
#        Validated Value (m3/hr) Validation Flag
# 0                         7.32               O
# ...

# %%
df_meter15 = pd.read_excel("data/raw/SES-Meter Data - 15mins.xlsx",sheet_name=None)

# %%
print(df_meter15.keys())
display(df_meter15['000F4252'])
# Out:
# dict_keys(['000F4252', '000F4253', '000F4258', '000F4259', '000F425B', '000F425C', '000F425D', '000F425E', '000F4261', '000F4263', '000F4266', '000F4267', '000F4268', '000F426A', '000F426B'])
#        Time Stamp  Calibrated Time Stamp              Date /Time  \
# 0      1571904910           1.571905e+09 2019-10-24 08:15:10.910
# 1      1571904962           1.571905e+09 2019-10-24 08:16:02.962
# 2      1571905202           1.571905e+09 2019-10-24 08:20:02.202
# 3      1571905252           1.571905e+09 2019-10-24 08:20:52.252
# 4      1571905331           1.571905e+09 2019-10-24 08:22:11.331
# ...           ...                    ...                     ...
# 21171  1590965445           1.590965e+09 2020-05-31 22:50:45.445
# 21172  1590966344           1.590966e+09 2020-05-31 23:05:44.344
# 21173  1590967243           1.590967e+09 2020-05-31 23:20:43.243
# 21174  1590968142           1.590968e+09 2020-05-31 23:35:42.142
# ...

# %%
df_meterd = pd.read_excel("data/raw/SES-Meter Data - Daily Reads.xlsx",sheet_name=None)
print(df_meterd.keys())
display(df_meterd['Additional Info'])
display(df_meterd['Meter 1'])
# Out:
# dict_keys(['Additional Info', 'Meter 1', 'Meter 2', 'Meter 3', 'Meter 4', 'Meter 5', 'Meter 6', 'Meter 7', 'Meter 8', 'Meter 9', 'Meter 10', 'Meter 11', 'Meter 12', 'Meter 13', 'Meter 14', 'Meter 15'])
#     UPRN Meter Number Postcode Install Date Portal access given to customer  \
# 0    NaN      Meter 1    RH8 9   2019-11-19                      2019-12-12
# 1    NaN     Meter 10    RH1 6   2019-11-19                      2019-11-27
# 2    NaN     Meter 11    RH6 9   2019-11-19                      2019-11-27
# 3    NaN     Meter 12    RH7 6   2019-11-19                      2019-11-27
# 4    NaN     Meter 13    RH7 6   2019-11-19                      2019-11-27
# 5    NaN     Meter 14    RH9 8   2019-11-19                      2019-12-12
# 6    NaN     Meter 15    RH5 4   2019-11-18                      2019-11-27
# 7    NaN      Meter 2   RH19 2   2019-10-24                      2019-10-31
# 8    NaN      Meter 3    RH8 0   2019-10-31                      2019-11-19
# ...

# %% [markdown]
# ### Conclusion
#
# SES datasets are incomplere: there is no link from the
